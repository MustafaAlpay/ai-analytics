# %% [markdown]
# # Sample EDA
# Quick peek at the bundled Iris sample and a tiny training run.

# %%
import pandas as pd

DATA_PATH = "../data/sample/iris_small.csv"
df = pd.read_csv(DATA_PATH)
df.describe(include="all")

# %%
from ai_analytics.pipeline import run_pipeline

metrics = run_pipeline(DATA_PATH, target="target", test_size=0.3)
metrics
